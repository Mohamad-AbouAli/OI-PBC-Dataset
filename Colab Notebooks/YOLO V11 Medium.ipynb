# %% [markdown]
# ✅ 1️⃣ Mount Google Drive

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ✅ 2️⃣ Set Up YOLOv8

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.5/983.5 kB 64.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# ✅ 3️⃣ Define Dataset Structure
#
# #/content/drive/MyDrive/PBC_YOLO/PBC_YOLO_811/PBC_YOLO_811
# │── /images
# │   │── /train
# │   │── /val
# │   │── /test
# │
# │── /labels
# │   │── /train
# │   │── /val
# │   │── /test
# │
# │── PBC_dataset.yaml  # YOLO dataset config file

# %% [markdown]
# ✅ 4️⃣ Create PBC_dataset.yaml

# %% [markdown]
# path:/content/drive/MyDrive/PBC_YOLO/PBC_YOLO_811/PBC_YOLO_811
# train: images/train
# val: images/val
# test: images/test
# names:
#   0: BA
#   1: BNE
#   2: EO
#   3: ERB
#   4: LY
#   5: MMY
#   6: MO
#   7: MY
#   8: PLT
#   9: PMY
#  10: RBC
#  11: SNE

# %%
from ultralytics import YOLO

# Load YOLO model (ensure correct name)
model = YOLO("yolo11m.pt")  # Replace with your model
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 38.8M/38.8M [00:00<00:00, 48.4MB/s]

# %% [markdown]
# ✅ 5️⃣ Train YOLOv8

# %%
# Train and enable logging
results = model.train(
    data="/content/drive/MyDrive/PBC_YOLO - 721/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    lr0=0.01,
    lrf=0.0001,
    momentum=0.937,
    weight_decay=0.0005,
    project='/content/drive/MyDrive/SavedModel/YOLO',  # Save directory
    name='YOLO11Medium721-Auto-Epoch100v3 Train-Val',  # Name for the run
    save=True,
    workers=8,
    patience=15,
    cos_lr = True,
    visualize = True,
    save_dir = "/content/drive/MyDrive/SavedModel/YOLO/YOLO11Medium721",
    plots=True  # Automatically saves training curves
)
# Out:
# Ultralytics 8.3.115 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# **Saving Model**

# %% [markdown]
# ✅ 6️⃣ Validate & Get Predictions
#
# This will automatically compute:
#
# *   Precision, Recall, mAP@50, mAP@50-95
# *   Confusion Matrix
# *   Per-class performance

# %%
# Run validation on the test set
metrics = results = model.val(data="/content/drive/MyDrive/PBC_YOLO - 721/data.yaml",
                              split="test",
                              project = "/content/drive/MyDrive/SavedModel/YOLO",
                              name='YOLO11Medium721-Auto-Epoch100v3 Test',
                              plots=True,)
# Out:
# Ultralytics 8.3.115 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,039,284 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.6±0.2 ms, read: 0.0±0.0 MB/s, size: 17.4 KB)
# val: Scanning /content/drive/MyDrive/PBC_YOLO - 721/labels/test.cache... 1688 images, 10 backgrounds, 1 corrupt: 100%|██████████| 1698/1698 [00:00<?, ?it/s]
# val: /content/drive/MyDrive/PBC_YOLO - 721/images/test/EO_76723.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0069]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 107/107 [01:29<00:00,  1.20it/s]
#                    all       1697      29772      0.876      0.919      0.931      0.853
#                     BA         94         94      0.933      0.989      0.989      0.915
#                    BNE        169        170       0.74      0.929      0.918      0.898
# ...

# %% [markdown]
# ✅ 7️⃣ mAP Metrics

# %% [markdown]
# ✅ 7️⃣ Validate Model & Generate Metrics

# %% [markdown]
# Classfication Repport

# %% [markdown]
# **Plot & Save Other Metrics**
#
# Precision-Recall Curve

# %% [markdown]
# mAP (Mean Average Precision) Curve

# %% [markdown]
# ✅ 7️⃣ Generate a Classification Report

# %% [markdown]
# 🎯 Next Steps:
#
# *   Train with more epochs (epochs=100)
# *   Try a larger model (yolov8m.pt, yolov8l.pt)
# *   Experiment with learning rate, augmentation, and batch size
